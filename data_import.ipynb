# %%
import neo4j


def connect_db():
    """
    function to create a client to neo4j.
    """
    driver = neo4j.GraphDatabase.driver(
        uri="neo4j://0.0.0.0:7687", auth=("neo4j", "password")
    )
    session = driver.session(database="neo4j")
    return session


def wipe_out_db(session):
    """
    function to wipe out existig data in neo4j before loading in the new data.
    """
    query = "match (node)-[relationship]->() delete node, relationship"
    session.run(query)

    query = "match (node) delete node"
    session.run(query)


session = connect_db()
wipe_out_db(session)

# %%
query = """
CREATE
  (user1: User {
    username: "john_doe",
    password: "P@ssw0rd1",
    name: "John Doe",
    email: "john.doe@example.com",
    date_of_birth: "1990-01-01",
    location: "New York",
    interests: ["Reading", "Travel", "Photography"],
    bio: "Explorer. Dreamer. Creator.",
    education: "New York University",
    occupation: "Software Engineer"
  }),
  (user2: User {
    username: "emily_smith",
    password: "Emsmith@123",
    name: "Emily Smith",
    email: "emily.smith@example.com",
    date_of_birth: "1985-05-12",
    location: "Chicago",
    interests: ["Cooking", "Gardening", "Cycling"],
    bio: "Passionate cook and urban gardener.",
    education: "University of Chicago",
    occupation: "Architect"
  }),
  (user3: User {
    username: "michael_brown",
    password: "M1ch@el321",
    name: "Michael Brown",
    email: "michael.brown@example.com",
    date_of_birth: "1992-07-22",
    location: "San Francisco",
    interests: ["Technology", "Basketball", "Gaming"],
    bio: "Tech enthusiast. Avid gamer. Sports fan.",
    education: "Stanford University",
    occupation: "Product Manager"
  }),
  (user4: User {
    username: "alex_jones",
    password: "Alex123!",
    name: "Alex Jones",
    email: "alex.jones@example.com",
    date_of_birth: "1988-09-15",
    location: "Miami",
    interests: ["Travel", "Photography", "Gaming"],
    bio: "Globe trotter and tech geek.",
    education: "University of Miami",
    occupation: "Graphic Designer"
  }),
  (user5: User {
    username: "sarah_connor",
    password: "SarahCon@321",
    name: "Sarah Connor",
    email: "sarah.connor@example.com",
    date_of_birth: "1991-11-30",
    location: "Seattle",
    interests: ["Reading", "Cycling", "Technology"],
    bio: "Book lover and tech enthusiast.",
    education: "University of Washington",
    occupation: "Software Engineer"
  }),
  (user6: User {
    username: "dave_martin",
    password: "D@veM4rtin",
    name: "Dave Martin",
    email: "dave.martin@example.com",
    date_of_birth: "1993-04-08",
    location: "Boston",
    interests: ["Cooking", "Travel", "Photography"],
    bio: "Chef at heart. Avid photographer.",
    education: "Massachusetts Institute of Technology",
    occupation: "Data Scientist"
  }),
  (user7: User {
    username: "lisa_white",
    password: "Lis@White88",
    name: "Lisa White",
    email: "lisa.white@example.com",
    date_of_birth: "1989-02-17",
    location: "Austin",
    interests: ["Gardening", "Gaming", "Reading"],
    bio: "Gamer and nature lover.",
    education: "University of Texas at Austin",
    occupation: "Product Manager"
  }),
  (user8: User {
    username: "kevin_lopez",
    password: "K3vin2023!",
    name: "Kevin Lopez",
    email: "kevin.lopez@example.com",
    date_of_birth: "1994-06-21",
    location: "Denver",
    interests: ["Cycling", "Technology", "Cooking"],
    bio: "Cycling enthusiast and tech guru.",
    education: "University of Colorado Boulder",
    occupation: "Architect"
  }),
  (user9: User {
    username: "natalie_porter",
    password: "N@talieP0rt!",
    name: "Natalie Porter",
    email: "natalie.porter@example.com",
    date_of_birth: "1987-12-03",
    location: "San Francisco",
    interests: ["Technology", "Reading", "Photography"],
    bio: "Tech lover and amateur photographer.",
    education: "Stanford University",
    occupation: "Product Manager"
  }),
  (user10: User {
    username: "brian_turner",
    password: "Bri@nT2023",
    name: "Brian Turner",
    email: "brian.turner@example.com",
    date_of_birth: "1990-08-25",
    location: "New York",
    interests: ["Cooking", "Gymming", "Travel"],
    bio: "Culinary wizard and world explorer.",
    education: "New York University",
    occupation: "Graphic Designer"
  }),
  (user11: User {
    username: "julie_chen",
    password: "Jul1eChen!",
    name: "Julie Chen",
    email: "julie.chen@example.com",
    date_of_birth: "1985-05-19",
    location: "Los Angeles",
    interests: ["Video Gaming", "Gymming", "Photography"],
    bio: "Gaming enthusiast and fitness lover.",
    education: "University of California, Los Angeles",
    occupation: "Software Engineer"
  }),
  (user12: User {
    username: "peter_griffin",
    password: "PeterG2023!",
    name: "Peter Griffin",
    email: "peter.griffin@example.com",
    date_of_birth: "1992-11-11",
    location: "Chicago",
    interests: ["Reading", "Travel", "Cycling"],
    bio: "Avid reader and cyclist.",
    education: "University of Chicago",
    occupation: "Data Scientist"
  }),
  (user13: User {
    username: "claire_murphy",
    password: "Cla1reM88",
    name: "Claire Murphy",
    email: "claire.murphy@example.com",
    date_of_birth: "1991-02-14",
    location: "Boston",
    interests: ["Photography", "Technology", "Reading"],
    bio: "Photographer and tech aficionado.",
    education: "Massachusetts Institute of Technology",
    occupation: "Architect"
  }),
  (user14: User {
    username: "mike_johnson",
    password: "MikeJ2023#",
    name: "Mike Johnson",
    email: "mike.johnson@example.com",
    date_of_birth: "1993-07-07",
    location: "Miami",
    interests: ["Gymming", "Gardening", "Gaming"],
    bio: "Fitness enthusiast and gamer.",
    education: "University of Miami",
    occupation: "Product Manager"
  }),
  (user15: User {
    username: "rachel_green",
    password: "RachelG!23",
    name: "Rachel Green",
    email: "rachel.green@example.com",
    date_of_birth: "1988-09-21",
    location: "Austin",
    interests: ["Cooking", "Photography", "Travel"],
    bio: "Passionate cook and world traveler.",
    education: "University of Texas at Austin",
    occupation: "Software Engineer"
  }),
  (user16: User {
    username: "chris_parker",
    password: "Chri$P@rker",
    name: "Chris Parker",
    email: "chris.parker@example.com",
    date_of_birth: "1994-03-15",
    location: "Seattle",
    interests: ["Cycling", "Technology", "Gardening"],
    bio: "Cyclist and tech enthusiast.",
    education: "University of Washington",
    occupation: "Data Scientist"
  }),
  (user17: User {
    username: "sophia_lopez",
    password: "SophiaL2023!",
    name: "Sophia Lopez",
    email: "sophia.lopez@example.com",
    date_of_birth: "1989-06-29",
    location: "Denver",
    interests: ["Reading", "Gymming", "Cooking"],
    bio: "Bookworm and fitness fanatic.",
    education: "University of Colorado Boulder",
    occupation: "Graphic Designer"
  }),
  (user18: User {
    username: "derek_morgan",
    password: "DerekM88#",
    name: "Derek Morgan",
    email: "derek.morgan@example.com",
    date_of_birth: "1992-01-20",
    location: "San Francisco",
    interests: ["Photography", "Travel", "Video Gaming"],
    bio: "Travel lover and gaming fan.",
    education: "Stanford University",
    occupation: "Architect"
  }),
  (user19: User {
    username: "emma_thompson",
    password: "EmmaT#2023",
    name: "Emma Thompson",
    email: "emma.thompson@example.com",
    date_of_birth: "1995-03-15",
    location: "New York",
    interests: ["Reading", "Photography", "Travel"],
    bio: "Book lover and aspiring photographer.",
    education: "New York University",
    occupation: "Data Scientist"
  }),
  (user20: User {
    username: "oliver_martin",
    password: "OliverM@123",
    name: "Oliver Martin",
    email: "oliver.martin@example.com",
    date_of_birth: "1986-07-22",
    location: "Seattle",
    interests: ["Technology", "Cycling", "Cooking"],
    bio: "Tech geek and outdoor enthusiast.",
    education: "University of Washington",
    occupation: "Software Engineer"
  }),
  (user21: User {
    username: "charlotte_lee",
    password: "Ch@rlotteL",
    name: "Charlotte Lee",
    email: "charlotte.lee@example.com",
    date_of_birth: "1990-10-08",
    location: "Chicago",
    interests: ["Gardening", "Reading", "Gymming"],
    bio: "Gardening aficionado and bookworm.",
    education: "University of Chicago",
    occupation: "Graphic Designer"
  }),
  (user22: User {
    username: "jack_smith",
    password: "JackS#2023",
    name: "Jack Smith",
    email: "jack.smith@example.com",
    date_of_birth: "1992-04-19",
    location: "Miami",
    interests: ["Video Gaming", "Travel", "Technology"],
    bio: "Gamer at heart. Tech-savvy traveler.",
    education: "University of Miami",
    occupation: "Product Manager"
  }),
  (user23: User {
    username: "amelia_johnson",
    password: "AmeliaJ88",
    name: "Amelia Johnson",
    email: "amelia.johnson@example.com",
    date_of_birth: "1993-05-21",
    location: "Boston",
    interests: ["Photography", "Gymming", "Cooking"],
    bio: "Photography lover and fitness enthusiast.",
    education: "Massachusetts Institute of Technology",
    occupation: "Architect"
  }),
  (user24: User {
    username: "lucas_williams",
    password: "LucasW2023",
    name: "Lucas Williams",
    email: "lucas.williams@example.com",
    date_of_birth: "1988-08-30",
    location: "Austin",
    interests: ["Cycling", "Gaming", "Technology"],
    bio: "Cycling fanatic and tech guru.",
    education: "University of Texas at Austin",
    occupation: "Software Engineer"
  }),
  (user25: User {
    username: "mia_davis",
    password: "MiaD#2023",
    name: "Mia Davis",
    email: "mia.davis@example.com",
    date_of_birth: "1994-09-14",
    location: "San Francisco",
    interests: ["Travel", "Reading", "Photography"],
    bio: "World traveler and avid reader.",
    education: "Stanford University",
    occupation: "Data Scientist"
  }),
  (user26: User {
    username: "mason_white",
    password: "MasonW88!",
    name: "Mason White",
    email: "mason.white@example.com",
    date_of_birth: "1989-06-03",
    location: "Denver",
    interests: ["Gymming", "Technology", "Cooking"],
    bio: "Fitness enthusiast and tech aficionado.",
    education: "University of Colorado Boulder",
    occupation: "Graphic Designer"
  }),
  (user27: User {
    username: "sophie_martinez",
    password: "SophieM2023",
    name: "Sophie Martinez",
    email: "sophie.martinez@example.com",
    date_of_birth: "1991-11-17",
    location: "Los Angeles",
    interests: ["Photography", "Gaming", "Gardening"],
    bio: "Photography lover and gaming enthusiast.",
    education: "University of California, Los Angeles",
    occupation: "Product Manager"
  }),
  (user28: User {
    username: "ethan_brown",
    password: "EthanB#2023",
    name: "Ethan Brown",
    email: "ethan.brown@example.com",
    date_of_birth: "1990-02-26",
    location: "New York",
    interests: ["Reading", "Technology", "Travel"],
    bio: "Tech-savvy bibliophile and explorer.",
    education: "New York University",
    occupation: "Architect"
  })

CREATE
  (user1)-[:IS_FRIEND_OF]->(user28), (user28)-[:IS_FRIEND_OF]->(user1),
  (user2)-[:IS_FRIEND_OF]->(user24), (user24)-[:IS_FRIEND_OF]->(user2),
  (user12)-[:IS_FRIEND_OF]->(user7), (user7)-[:IS_FRIEND_OF]->(user12),
  (user3)-[:IS_FRIEND_OF]->(user19), (user19)-[:IS_FRIEND_OF]->(user3),
  (user4)-[:IS_FRIEND_OF]->(user15), (user15)-[:IS_FRIEND_OF]->(user4),
  (user5)-[:IS_FRIEND_OF]->(user11), (user11)-[:IS_FRIEND_OF]->(user5),
  (user6)-[:IS_FRIEND_OF]->(user18), (user18)-[:IS_FRIEND_OF]->(user6),
  (user8)-[:IS_FRIEND_OF]->(user22), (user22)-[:IS_FRIEND_OF]->(user8),
  (user9)-[:IS_FRIEND_OF]->(user16), (user16)-[:IS_FRIEND_OF]->(user9),
  (user10)-[:IS_FRIEND_OF]->(user26), (user26)-[:IS_FRIEND_OF]->(user10),
  (user13)-[:IS_FRIEND_OF]->(user21), (user21)-[:IS_FRIEND_OF]->(user13),
  (user14)-[:IS_FRIEND_OF]->(user27), (user27)-[:IS_FRIEND_OF]->(user14),
  (user17)-[:IS_FRIEND_OF]->(user23), (user23)-[:IS_FRIEND_OF]->(user17),
  (user20)-[:IS_FRIEND_OF]->(user25), (user25)-[:IS_FRIEND_OF]->(user20),
  (user1)-[:IS_FRIEND_OF]->(user4), (user4)-[:IS_FRIEND_OF]->(user1),
  (user2)-[:IS_FRIEND_OF]->(user5), (user5)-[:IS_FRIEND_OF]->(user2),
  (user3)-[:IS_FRIEND_OF]->(user6), (user6)-[:IS_FRIEND_OF]->(user3),
  (user7)-[:IS_FRIEND_OF]->(user8), (user8)-[:IS_FRIEND_OF]->(user7),
  (user9)-[:IS_FRIEND_OF]->(user10), (user10)-[:IS_FRIEND_OF]->(user9),
  (user11)-[:IS_FRIEND_OF]->(user12), (user12)-[:IS_FRIEND_OF]->(user11),
  (user13)-[:IS_FRIEND_OF]->(user14), (user14)-[:IS_FRIEND_OF]->(user13),
  (user15)-[:IS_FRIEND_OF]->(user16), (user16)-[:IS_FRIEND_OF]->(user15),
  (user17)-[:IS_FRIEND_OF]->(user18), (user18)-[:IS_FRIEND_OF]->(user17),
  (user19)-[:IS_FRIEND_OF]->(user20), (user20)-[:IS_FRIEND_OF]->(user19),
  (user21)-[:IS_FRIEND_OF]->(user22), (user22)-[:IS_FRIEND_OF]->(user21),
  (user23)-[:IS_FRIEND_OF]->(user24), (user24)-[:IS_FRIEND_OF]->(user23),
  (user25)-[:IS_FRIEND_OF]->(user26), (user26)-[:IS_FRIEND_OF]->(user25),
  (user27)-[:IS_FRIEND_OF]->(user28), (user28)-[:IS_FRIEND_OF]->(user27),
  (user2)-[:IS_FRIEND_OF]->(user13), (user13)-[:IS_FRIEND_OF]->(user2),
  (user3)-[:IS_FRIEND_OF]->(user14), (user14)-[:IS_FRIEND_OF]->(user3),
  (user4)-[:IS_FRIEND_OF]->(user15), (user15)-[:IS_FRIEND_OF]->(user4),
  (user5)-[:IS_FRIEND_OF]->(user16), (user16)-[:IS_FRIEND_OF]->(user5),
  (user6)-[:IS_FRIEND_OF]->(user17), (user17)-[:IS_FRIEND_OF]->(user6),
  (user7)-[:IS_FRIEND_OF]->(user18), (user18)-[:IS_FRIEND_OF]->(user7),
  (user8)-[:IS_FRIEND_OF]->(user19), (user19)-[:IS_FRIEND_OF]->(user8),
  (user9)-[:IS_FRIEND_OF]->(user20), (user20)-[:IS_FRIEND_OF]->(user9),
  (user10)-[:IS_FRIEND_OF]->(user21), (user21)-[:IS_FRIEND_OF]->(user10),
  (user11)-[:IS_FRIEND_OF]->(user22), (user22)-[:IS_FRIEND_OF]->(user11),
  (user12)-[:IS_FRIEND_OF]->(user23), (user23)-[:IS_FRIEND_OF]->(user12),
  (user1)-[:IS_FRIEND_OF]->(user24), (user24)-[:IS_FRIEND_OF]->(user1),
  (user2)-[:IS_FRIEND_OF]->(user25), (user25)-[:IS_FRIEND_OF]->(user2),
  (user3)-[:IS_FRIEND_OF]->(user26), (user26)-[:IS_FRIEND_OF]->(user3),
  (user4)-[:IS_FRIEND_OF]->(user27), (user27)-[:IS_FRIEND_OF]->(user4),
  (user5)-[:IS_FRIEND_OF]->(user28), (user28)-[:IS_FRIEND_OF]->(user5),
  (user1)-[:IS_FRIEND_OF]->(user3), (user3)-[:IS_FRIEND_OF]->(user1),
  (user1)-[:IS_FRIEND_OF]->(user5), (user5)-[:IS_FRIEND_OF]->(user1),
  (user1)-[:IS_FRIEND_OF]->(user9), (user9)-[:IS_FRIEND_OF]->(user1),
  (user1)-[:IS_FRIEND_OF]->(user12), (user12)-[:IS_FRIEND_OF]->(user1),
  (user1)-[:IS_FRIEND_OF]->(user17), (user17)-[:IS_FRIEND_OF]->(user1),
  (user2)-[:IS_FRIEND_OF]->(user6), (user6)-[:IS_FRIEND_OF]->(user2),
  (user2)-[:IS_FRIEND_OF]->(user8), (user8)-[:IS_FRIEND_OF]->(user2),
  (user2)-[:IS_FRIEND_OF]->(user10), (user10)-[:IS_FRIEND_OF]->(user2),
  (user2)-[:IS_FRIEND_OF]->(user13), (user13)-[:IS_FRIEND_OF]->(user2),
  (user2)-[:IS_FRIEND_OF]->(user18), (user18)-[:IS_FRIEND_OF]->(user2),
  (user3)-[:IS_FRIEND_OF]->(user7), (user7)-[:IS_FRIEND_OF]->(user3),
  (user3)-[:IS_FRIEND_OF]->(user11), (user11)-[:IS_FRIEND_OF]->(user3),
  (user3)-[:IS_FRIEND_OF]->(user14), (user14)-[:IS_FRIEND_OF]->(user3),
  (user3)-[:IS_FRIEND_OF]->(user19), (user19)-[:IS_FRIEND_OF]->(user3),
  (user4)-[:IS_FRIEND_OF]->(user8), (user8)-[:IS_FRIEND_OF]->(user4),
  (user4)-[:IS_FRIEND_OF]->(user12), (user12)-[:IS_FRIEND_OF]->(user4),
  (user4)-[:IS_FRIEND_OF]->(user16), (user16)-[:IS_FRIEND_OF]->(user4),
  (user4)-[:IS_FRIEND_OF]->(user20), (user20)-[:IS_FRIEND_OF]->(user4),
  (user5)-[:IS_FRIEND_OF]->(user10), (user10)-[:IS_FRIEND_OF]->(user5),
  (user5)-[:IS_FRIEND_OF]->(user13), (user13)-[:IS_FRIEND_OF]->(user5),
  (user5)-[:IS_FRIEND_OF]->(user21), (user21)-[:IS_FRIEND_OF]->(user5),
  (user6)-[:IS_FRIEND_OF]->(user9), (user9)-[:IS_FRIEND_OF]->(user6),
  (user6)-[:IS_FRIEND_OF]->(user14), (user14)-[:IS_FRIEND_OF]->(user6),
  (user6)-[:IS_FRIEND_OF]->(user22), (user22)-[:IS_FRIEND_OF]->(user6),
  (user7)-[:IS_FRIEND_OF]->(user11), (user11)-[:IS_FRIEND_OF]->(user7),
  (user7)-[:IS_FRIEND_OF]->(user15), (user15)-[:IS_FRIEND_OF]->(user7),
  (user7)-[:IS_FRIEND_OF]->(user23), (user23)-[:IS_FRIEND_OF]->(user7),
  (user8)-[:IS_FRIEND_OF]->(user10), (user10)-[:IS_FRIEND_OF]->(user8),
  (user8)-[:IS_FRIEND_OF]->(user16), (user16)-[:IS_FRIEND_OF]->(user8),
  (user8)-[:IS_FRIEND_OF]->(user24), (user24)-[:IS_FRIEND_OF]->(user8),
  (user9)-[:IS_FRIEND_OF]->(user17), (user17)-[:IS_FRIEND_OF]->(user9),
  (user9)-[:IS_FRIEND_OF]->(user25), (user25)-[:IS_FRIEND_OF]->(user9),
  (user10)-[:IS_FRIEND_OF]->(user18), (user18)-[:IS_FRIEND_OF]->(user10),
  (user10)-[:IS_FRIEND_OF]->(user26), (user26)-[:IS_FRIEND_OF]->(user10),
  (user11)-[:IS_FRIEND_OF]->(user19), (user19)-[:IS_FRIEND_OF]->(user11),
  (user12)-[:IS_FRIEND_OF]->(user20), (user20)-[:IS_FRIEND_OF]->(user12),
  (user12)-[:IS_FRIEND_OF]->(user28), (user28)-[:IS_FRIEND_OF]->(user12),
  (user13)-[:IS_FRIEND_OF]->(user21), (user21)-[:IS_FRIEND_OF]->(user13),
  (user13)-[:IS_FRIEND_OF]->(user22), (user22)-[:IS_FRIEND_OF]->(user13),
  (user14)-[:IS_FRIEND_OF]->(user23), (user23)-[:IS_FRIEND_OF]->(user14),
  (user14)-[:IS_FRIEND_OF]->(user24), (user24)-[:IS_FRIEND_OF]->(user14),
  (user15)-[:IS_FRIEND_OF]->(user25), (user25)-[:IS_FRIEND_OF]->(user15),
  (user15)-[:IS_FRIEND_OF]->(user26), (user26)-[:IS_FRIEND_OF]->(user15),
  (user16)-[:IS_FRIEND_OF]->(user27), (user27)-[:IS_FRIEND_OF]->(user16),
  (user16)-[:IS_FRIEND_OF]->(user28), (user28)-[:IS_FRIEND_OF]->(user16),
  (user17)-[:IS_FRIEND_OF]->(user18), (user18)-[:IS_FRIEND_OF]->(user17),
  (user17)-[:IS_FRIEND_OF]->(user19), (user19)-[:IS_FRIEND_OF]->(user17),
  (user18)-[:IS_FRIEND_OF]->(user20), (user20)-[:IS_FRIEND_OF]->(user18),
  (user18)-[:IS_FRIEND_OF]->(user21), (user21)-[:IS_FRIEND_OF]->(user18),
  (user19)-[:IS_FRIEND_OF]->(user22), (user22)-[:IS_FRIEND_OF]->(user19),
  (user19)-[:IS_FRIEND_OF]->(user23), (user23)-[:IS_FRIEND_OF]->(user19),
  (user20)-[:IS_FRIEND_OF]->(user24), (user24)-[:IS_FRIEND_OF]->(user20),
  (user20)-[:IS_FRIEND_OF]->(user25), (user25)-[:IS_FRIEND_OF]->(user20),
  (user21)-[:IS_FRIEND_OF]->(user26), (user26)-[:IS_FRIEND_OF]->(user21),
  (user21)-[:IS_FRIEND_OF]->(user27), (user27)-[:IS_FRIEND_OF]->(user21),
  (user22)-[:IS_FRIEND_OF]->(user28), (user28)-[:IS_FRIEND_OF]->(user22),
  (user22)-[:IS_FRIEND_OF]->(user1), (user1)-[:IS_FRIEND_OF]->(user22),
  (user23)-[:IS_FRIEND_OF]->(user2), (user2)-[:IS_FRIEND_OF]->(user23),
  (user23)-[:IS_FRIEND_OF]->(user3), (user3)-[:IS_FRIEND_OF]->(user23),
  (user24)-[:IS_FRIEND_OF]->(user4), (user4)-[:IS_FRIEND_OF]->(user24),
  (user24)-[:IS_FRIEND_OF]->(user5), (user5)-[:IS_FRIEND_OF]->(user24),
  (user25)-[:IS_FRIEND_OF]->(user6), (user6)-[:IS_FRIEND_OF]->(user25),
  (user25)-[:IS_FRIEND_OF]->(user7), (user7)-[:IS_FRIEND_OF]->(user25),
  (user26)-[:IS_FRIEND_OF]->(user8), (user8)-[:IS_FRIEND_OF]->(user26),
  (user26)-[:IS_FRIEND_OF]->(user9), (user9)-[:IS_FRIEND_OF]->(user26),
  (user27)-[:IS_FRIEND_OF]->(user10), (user10)-[:IS_FRIEND_OF]->(user27),
  (user27)-[:IS_FRIEND_OF]->(user11), (user11)-[:IS_FRIEND_OF]->(user27),
  (user28)-[:IS_FRIEND_OF]->(user12), (user12)-[:IS_FRIEND_OF]->(user28),
  (user28)-[:IS_FRIEND_OF]->(user13), (user13)-[:IS_FRIEND_OF]->(user28)

CREATE
  (post1: Post {
    id: "post1",
    timestamp: "2023-11-15T08:30:00",
    content: "Exploring the beautiful trails of Yosemite this weekend! #nature #hiking"
  }),
  (comment1: Comment {
    id: "comment1",
    text: "Looks amazing! Have fun!",
    timestamp: "2023-11-15T09:00:00"
  }),
  (comment2: Comment {
    id: "comment2",
    text: "Yosemite is on my bucket list too!",
    timestamp: "2023-11-15T09:30:00"
  }),
  (user5)-[:CREATED]->(post1),
  (user6)-[:CREATED]->(comment1),
  (user8)-[:CREATED]->(comment2),
  (post1)-[:HAS_COMMENT]->(comment1),
  (post1)-[:HAS_COMMENT]->(comment2),
  (user1)-[:LIKED]->(post1),
  (user11)-[:LIKED]->(post1),
  (user16)-[:LIKED]->(post1),
  (user12)-[:LIKED]->(post1),
  (user17)-[:LIKED]->(post1),
  (user16)-[:LIKED]->(comment1),
  (user25)-[:LIKED]->(comment1),
  (user11)-[:LIKED]->(comment1),
  (user18)-[:LIKED]->(comment2),
  (user21)-[:LIKED]->(comment2)

CREATE
  (post2: Post {
    id: "post2",
    timestamp: "2023-11-16T10:00:00",
    content: "Just finished reading a fantastic book on space exploration. #Astronomy"
  }),
  (comment3: Comment {
    id: "comment3",
    text: "Which book was it? I'd love to check it out!",
    timestamp: "2023-11-16T10:30:00"
  }),
  (comment4: Comment {
    id: "comment4",
    text: "Space has always fascinated me since childhood!",
    timestamp: "2023-11-16T11:00:00"
  }),
  (user2)-[:CREATED]->(post2),
  (user4)-[:CREATED]->(comment3),
  (user7)-[:CREATED]->(comment4),
  (post2)-[:HAS_COMMENT]->(comment3),
  (post2)-[:HAS_COMMENT]->(comment4),
  (user8)-[:LIKED]->(post2),
  (user14)-[:LIKED]->(post2),
  (user22)-[:LIKED]->(post2),
  (user28)-[:LIKED]->(post2),
  (user18)-[:LIKED]->(comment3),
  (user20)-[:LIKED]->(comment3),
  (user6)-[:LIKED]->(comment3),
  (user19)-[:LIKED]->(comment4),
  (user23)-[:LIKED]->(comment4)

CREATE
  (post3: Post {
    id: "post3",
    timestamp: "2023-11-17T09:15:00",
    content: "Enjoying a relaxing day at the beach. #SunnyDays"
  }),
  (comment5: Comment {
    id: "comment5",
    text: "That looks like the perfect way to unwind!",
    timestamp: "2023-11-17T09:45:00"
  }),
  (comment6: Comment {
    id: "comment6",
    text: "Which beach is this? It looks beautiful!",
    timestamp: "2023-11-17T10:05:00"
  }),
  (user10)-[:CREATED]->(post3),
  (user12)-[:CREATED]->(comment5),
  (user15)-[:CREATED]->(comment6),
  (post3)-[:HAS_COMMENT]->(comment5),
  (post3)-[:HAS_COMMENT]->(comment6),
  (user21)-[:LIKED]->(post3),
  (user26)-[:LIKED]->(post3),
  (user27)-[:LIKED]->(post3),
  (user9)-[:LIKED]->(post3),
  (user1)-[:LIKED]->(comment5),
  (user13)-[:LIKED]->(comment5),
  (user17)-[:LIKED]->(comment5),
  (user24)-[:LIKED]->(comment6),
  (user3)-[:LIKED]->(comment6)

  CREATE
  (post4: Post {
    id: "post4",
    timestamp: "2023-11-18T15:00:00",
    content: "Incredible sunset view from the mountain top! #HikingAdventures"
  }),
  (comment7: Comment {
    id: "comment7",
    text: "That's an amazing view! Which trail did you take?",
    timestamp: "2023-11-18T15:30:00"
  }),
  (comment8: Comment {
    id: "comment8",
    text: "Sunsets in the mountains are the best. 🌄",
    timestamp: "2023-11-18T16:00:00"
  }),
  (user3)-[:CREATED]->(post4),
  (user14)-[:CREATED]->(comment7),
  (user17)-[:CREATED]->(comment8),
  (post4)-[:HAS_COMMENT]->(comment7),
  (post4)-[:HAS_COMMENT]->(comment8),
  (user2)-[:LIKED]->(post4),
  (user5)-[:LIKED]->(post4),
  (user8)-[:LIKED]->(post4),
  (user11)-[:LIKED]->(comment7),
  (user15)-[:LIKED]->(comment7),
  (user19)-[:LIKED]->(comment8),
  (user21)-[:LIKED]->(comment8)

CREATE
  (post5: Post {
    id: "post5",
    timestamp: "2023-11-19T09:45:00",
    content: "Early morning jog in the park. Feeling refreshed! #MorningRun"
  }),
  (comment9: Comment {
    id: "comment9",
    text: "Jogging is a great way to start the day!",
    timestamp: "2023-11-19T10:15:00"
  }),
  (comment10: Comment {
    id: "comment10",
    text: "I wish I could get up that early 😴",
    timestamp: "2023-11-19T10:30:00"
  }),
  (user6)-[:CREATED]->(post5),
  (user20)-[:CREATED]->(comment9),
  (user24)-[:CREATED]->(comment10),
  (post5)-[:HAS_COMMENT]->(comment9),
  (post5)-[:HAS_COMMENT]->(comment10),
  (user1)-[:LIKED]->(post5),
  (user4)-[:LIKED]->(post5),
  (user7)-[:LIKED]->(post5),
  (user10)-[:LIKED]->(comment9),
  (user13)-[:LIKED]->(comment9),
  (user16)-[:LIKED]->(comment10),
  (user22)-[:LIKED]->(comment10)

CREATE
  (post6: Post {
    id: "post6",
    timestamp: "2023-11-20T12:00:00",
    content: "Finally tried the new Italian restaurant in town. Absolutely delicious! #Foodie"
  }),
  (comment11: Comment {
    id: "comment11",
    text: "Their pasta dishes are the best! 🍝",
    timestamp: "2023-11-20T12:30:00"
  }),
  (comment12: Comment {
    id: "comment12",
    text: "Need to check this place out. Thanks for the recommendation!",
    timestamp: "2023-11-20T13:00:00"
  }),
  (user9)-[:CREATED]->(post6),
  (user23)-[:CREATED]->(comment11),
  (user26)-[:CREATED]->(comment12),
  (post6)-[:HAS_COMMENT]->(comment11),
  (post6)-[:HAS_COMMENT]->(comment12),
  (user3)-[:LIKED]->(post6),
  (user12)-[:LIKED]->(post6),
  (user18)-[:LIKED]->(post6),
  (user5)-[:LIKED]->(comment11),
  (user14)-[:LIKED]->(comment11),
  (user20)-[:LIKED]->(comment12),
  (user28)-[:LIKED]->(comment12)

CREATE
  (post7: Post {
    id: "post7",
    timestamp: "2023-11-21T14:00:00",
    content: "Had a great time at the jazz festival this weekend! 🎷 #JazzLover"
  }),
  (comment13: Comment {
    id: "comment13",
    text: "Jazz festivals always have such a great atmosphere.",
    timestamp: "2023-11-21T14:30:00"
  }),
  (comment14: Comment {
    id: "comment14",
    text: "Who was your favorite performer?",
    timestamp: "2023-11-21T15:00:00"
  }),
  (user25)-[:CREATED]->(post7),
  (user2)-[:CREATED]->(comment13),
  (user5)-[:CREATED]->(comment14),
  (post7)-[:HAS_COMMENT]->(comment13),
  (post7)-[:HAS_COMMENT]->(comment14),
  (user10)-[:LIKED]->(post7),
  (user15)-[:LIKED]->(post7),
  (user20)-[:LIKED]->(post7),
  (user4)-[:LIKED]->(comment13),
  (user7)-[:LIKED]->(comment13),
  (user11)-[:LIKED]->(comment14),
  (user16)-[:LIKED]->(comment14)

CREATE
  (post8: Post {
    id: "post8",
    timestamp: "2023-11-22T08:45:00",
    content: "Sunrise yoga sessions are the best way to start the day. #YogaLife"
  }),
  (comment15: Comment {
    id: "comment15",
    text: "Completely agree! It's so rejuvenating.",
    timestamp: "2023-11-22T09:00:00"
  }),
  (comment16: Comment {
    id: "comment16",
    text: "Do you have any yoga routine suggestions for beginners?",
    timestamp: "2023-11-22T09:15:00"
  }),
  (user3)-[:CREATED]->(post8),
  (user8)-[:CREATED]->(comment15),
  (user12)-[:CREATED]->(comment16),
  (post8)-[:HAS_COMMENT]->(comment15),
  (post8)-[:HAS_COMMENT]->(comment16),
  (user1)-[:LIKED]->(post8),
  (user6)-[:LIKED]->(post8),
  (user9)-[:LIKED]->(post8),
  (user13)-[:LIKED]->(comment15),
  (user17)-[:LIKED]->(comment15),
  (user21)-[:LIKED]->(comment16),
  (user24)-[:LIKED]->(comment16)

CREATE
  (post9: Post {
    id: "post9",
    timestamp: "2023-11-23T17:30:00",
    content: "Nothing beats homemade apple pie! #Baking"
  }),
  (comment17: Comment {
    id: "comment17",
    text: "That looks delicious! Can you share the recipe?",
    timestamp: "2023-11-23T18:00:00"
  }),
  (comment18: Comment {
    id: "comment18",
    text: "I agree! Apple pie is the best comfort food.",
    timestamp: "2023-11-23T18:30:00"
  }),
  (user18)-[:CREATED]->(post9),
  (user22)-[:CREATED]->(comment17),
  (user26)-[:CREATED]->(comment18),
  (post9)-[:HAS_COMMENT]->(comment17),
  (post9)-[:HAS_COMMENT]->(comment18),
  (user2)-[:LIKED]->(post9),
  (user4)-[:LIKED]->(post9),
  (user7)-[:LIKED]->(post9),
  (user11)-[:LIKED]->(comment17),
  (user14)-[:LIKED]->(comment17),
  (user19)-[:LIKED]->(comment18),
  (user23)-[:LIKED]->(comment18)

CREATE
  (post10: Post {
    id: "post10",
    timestamp: "2023-11-24T13:00:00",
    content: "Check out this cool street art I found in the city today! #StreetArt #UrbanExploration"
  }),
  (comment19: Comment {
    id: "comment19",
    text: "This is really unique! Which street is this on?",
    timestamp: "2023-11-24T13:30:00"
  }),
  (comment20: Comment {
    id: "comment20",
    text: "I love discovering art like this. Always a nice surprise!",
    timestamp: "2023-11-24T14:00:00"
  }),
  (user27)-[:CREATED]->(post10),
  (user9)-[:CREATED]->(comment19),
  (user13)-[:CREATED]->(comment20),
  (post10)-[:HAS_COMMENT]->(comment19),
  (post10)-[:HAS_COMMENT]->(comment20),
  (user1)-[:LIKED]->(post10),
  (user4)-[:LIKED]->(post10),
  (user7)-[:LIKED]->(post10),
  (user15)-[:LIKED]->(comment19),
  (user17)-[:LIKED]->(comment19),
  (user22)-[:LIKED]->(comment20),
  (user25)-[:LIKED]->(comment20)

CREATE
  (post11: Post {
    id: "post11",
    timestamp: "2023-11-25T10:45:00",
    content: "Early morning paddleboarding session. So peaceful! #Paddleboarding #MorningVibes"
  }),
  (comment21: Comment {
    id: "comment21",
    text: "Looks so serene. I need to try paddleboarding!",
    timestamp: "2023-11-25T11:15:00"
  }),
  (comment22: Comment {
    id: "comment22",
    text: "Perfect way to start the day!",
    timestamp: "2023-11-25T11:30:00"
  }),
  (user6)-[:CREATED]->(post11),
  (user16)-[:CREATED]->(comment21),
  (user20)-[:CREATED]->(comment22),
  (post11)-[:HAS_COMMENT]->(comment21),
  (post11)-[:HAS_COMMENT]->(comment22),
  (user2)-[:LIKED]->(post11),
  (user5)-[:LIKED]->(post11),
  (user8)-[:LIKED]->(post11),
  (user12)-[:LIKED]->(comment21),
  (user18)-[:LIKED]->(comment21),
  (user23)-[:LIKED]->(comment22),
  (user26)-[:LIKED]->(comment22)

CREATE
  (post12: Post {
    id: "post12",
    timestamp: "2023-11-26T18:00:00",
    content: "Spent the day volunteering at the local animal shelter. So rewarding! #Volunteering #AnimalLover"
  }),
  (comment23: Comment {
    id: "comment23",
    text: "That's awesome! Animals bring so much joy.",
    timestamp: "2023-11-26T18:30:00"
  }),
  (comment24: Comment {
    id: "comment24",
    text: "I've been thinking about volunteering too. Thanks for the inspiration!",
    timestamp: "2023-11-26T19:00:00"
  }),
  (user19)-[:CREATED]->(post12),
  (user21)-[:CREATED]->(comment23),
  (user23)-[:CREATED]->(comment24),
  (post12)-[:HAS_COMMENT]->(comment23),
  (post12)-[:HAS_COMMENT]->(comment24),
  (user3)-[:LIKED]->(post12),
  (user5)-[:LIKED]->(post12),
  (user11)-[:LIKED]->(post12),
  (user13)-[:LIKED]->(comment23),
  (user15)-[:LIKED]->(comment23),
  (user17)-[:LIKED]->(comment24),
  (user26)-[:LIKED]->(comment24)

CREATE
  (post13: Post {
    id: "post13",
    timestamp: "2023-11-27T20:00:00",
    content: "Attended a fascinating lecture on renewable energy today. #Sustainability #RenewableEnergy"
  }),
  (comment25: Comment {
    id: "comment25",
    text: "The future is renewable! Would love to hear more about the lecture.",
    timestamp: "2023-11-27T20:30:00"
  }),
  (comment26: Comment {
    id: "comment26",
    text: "It's great to see more people getting interested in sustainable energy!",
    timestamp: "2023-11-27T21:00:00"
  }),
  (user14)-[:CREATED]->(post13),
  (user18)-[:CREATED]->(comment25),
  (user22)-[:CREATED]->(comment26),
  (post13)-[:HAS_COMMENT]->(comment25),
  (post13)-[:HAS_COMMENT]->(comment26),
  (user1)-[:LIKED]->(post13),
  (user4)-[:LIKED]->(post13),
  (user7)-[:LIKED]->(post13),
  (user9)-[:LIKED]->(comment25),
  (user12)-[:LIKED]->(comment25),
  (user16)-[:LIKED]->(comment26),
  (user20)-[:LIKED]->(comment26)

CREATE
  (post14: Post {
    id: "post14",
    timestamp: "2023-11-28T08:15:00",
    content: "Nothing beats a fresh cup of coffee to start the morning. #CoffeeLover"
  }),
  (comment27: Comment {
    id: "comment27",
    text: "Agreed! Coffee is the best way to kickstart the day.",
    timestamp: "2023-11-28T08:45:00"
  }),
  (comment28: Comment {
    id: "comment28",
    text: "What's your favorite coffee blend?",
    timestamp: "2023-11-28T09:00:00"
  }),
  (user8)-[:CREATED]->(post14),
  (user10)-[:CREATED]->(comment27),
  (user12)-[:CREATED]->(comment28),
  (post14)-[:HAS_COMMENT]->(comment27),
  (post14)-[:HAS_COMMENT]->(comment28),
  (user2)-[:LIKED]->(post14),
  (user4)-[:LIKED]->(post14),
  (user6)-[:LIKED]->(post14),
  (user14)-[:LIKED]->(comment27),
  (user16)-[:LIKED]->(comment27),
  (user18)-[:LIKED]->(comment28),
  (user20)-[:LIKED]->(comment28)

CREATE
  (post15: Post {
    id: "post15",
    timestamp: "2023-11-29T12:30:00",
    content: "Exploring the local farmers' market. So many fresh goodies! #FarmersMarket"
  }),
  (comment29: Comment {
    id: "comment29",
    text: "Farmers' markets are great for finding organic produce.",
    timestamp: "2023-11-29T13:00:00"
  }),
  (comment30: Comment {
    id: "comment30",
    text: "Did you find any interesting fruits or vegetables?",
    timestamp: "2023-11-29T13:30:00"
  }),
  (user7)-[:CREATED]->(post15),
  (user9)-[:CREATED]->(comment29),
  (user11)-[:CREATED]->(comment30),
  (post15)-[:HAS_COMMENT]->(comment29),
  (post15)-[:HAS_COMMENT]->(comment30),
  (user3)-[:LIKED]->(post15),
  (user5)-[:LIKED]->(post15),
  (user13)-[:LIKED]->(post15),
  (user15)-[:LIKED]->(comment29),
  (user17)-[:LIKED]->(comment29),
  (user19)-[:LIKED]->(comment30),
  (user21)-[:LIKED]->(comment30)

CREATE
  (post16: Post {
    id: "post16",
    timestamp: "2023-11-30T17:45:00",
    content: "Can't believe I finished my first half-marathon today! #RunningGoals"
  }),
  (comment31: Comment {
    id: "comment31",
    text: "Congratulations on this huge achievement!",
    timestamp: "2023-11-30T18:15:00"
  }),
  (comment32: Comment {
    id: "comment32",
    text: "That's so inspiring! Any tips for beginners?",
    timestamp: "2023-11-30T18:45:00"
  }),
  (user26)-[:CREATED]->(post16),
  (user24)-[:CREATED]->(comment31),
  (user22)-[:CREATED]->(comment32),
  (post16)-[:HAS_COMMENT]->(comment31),
  (post16)-[:HAS_COMMENT]->(comment32),
  (user23)-[:LIKED]->(post16),
  (user25)-[:LIKED]->(post16),
  (user27)-[:LIKED]->(post16),
  (user28)-[:LIKED]->(comment31),
  (user2)-[:LIKED]->(comment31),
  (user4)-[:LIKED]->(comment32),
  (user6)-[:LIKED]->(comment32)

CREATE
  (post17: Post {
    id: "post17",
    timestamp: "2023-12-01T10:00:00",
    content: "Watching the sunrise over the ocean is magical. #PeacefulMornings"
  }),
  (comment33: Comment {
    id: "comment33",
    text: "It's moments like these that make life beautiful.",
    timestamp: "2023-12-01T10:30:00"
  }),
  (comment34: Comment {
    id: "comment34",
    text: "I need to wake up early and experience this!",
    timestamp: "2023-12-01T11:00:00"
  }),
  (user1)-[:CREATED]->(post17),
  (user3)-[:CREATED]->(comment33),
  (user5)-[:CREATED]->(comment34),
  (post17)-[:HAS_COMMENT]->(comment33),
  (post17)-[:HAS_COMMENT]->(comment34),
  (user7)-[:LIKED]->(post17),
  (user9)-[:LIKED]->(post17),
  (user11)-[:LIKED]->(post17),
  (user13)-[:LIKED]->(comment33),
  (user15)-[:LIKED]->(comment33),
  (user17)-[:LIKED]->(comment34),
  (user19)-[:LIKED]->(comment34)

CREATE
  (post18: Post {
    id: "post18",
    timestamp: "2023-12-02T15:30:00",
    content: "Learning to bake bread from scratch. The aroma is amazing! #Baking"
  }),
  (comment35: Comment {
    id: "comment35",
    text: "Homemade bread is the best. Enjoy!",
    timestamp: "2023-12-02T16:00:00"
  }),
  (comment36: Comment {
    id: "comment36",
    text: "Do you have a favorite recipe to share?",
    timestamp: "2023-12-02T16:30:00"
  }),
  (user20)-[:CREATED]->(post18),
  (user18)-[:CREATED]->(comment35),
  (user16)-[:CREATED]->(comment36),
  (post18)-[:HAS_COMMENT]->(comment35),
  (post18)-[:HAS_COMMENT]->(comment36),
  (user14)-[:LIKED]->(post18),
  (user12)-[:LIKED]->(post18),
  (user10)-[:LIKED]->(post18),
  (user8)-[:LIKED]->(comment35),
  (user6)-[:LIKED]->(comment35),
  (user4)-[:LIKED]->(comment36),
  (user2)-[:LIKED]->(comment36)

CREATE
  (post19: Post {
    id: "post19",
    timestamp: "2023-12-03T20:15:00",
    content: "Stargazing tonight. The sky is so clear! #Stargazing"
  }),
  (comment37: Comment {
    id: "comment37",
    text: "There's nothing like a starry night to remind us of the universe's wonders.",
    timestamp: "2023-12-03T20:45:00"
  }),
  (comment38: Comment {
    id: "comment38",
    text: "Did you manage to spot any constellations?",
    timestamp: "2023-12-03T21:15:00"
  }),
  (user28)-[:CREATED]->(post19),
  (user26)-[:CREATED]->(comment37),
  (user24)-[:CREATED]->(comment38),
  (post19)-[:HAS_COMMENT]->(comment37),
  (post19)-[:HAS_COMMENT]->(comment38),
  (user22)-[:LIKED]->(post19),
  (user20)-[:LIKED]->(post19),
  (user18)-[:LIKED]->(post19),
  (user16)-[:LIKED]->(comment37),
  (user14)-[:LIKED]->(comment37),
  (user12)-[:LIKED]->(comment38),
  (user10)-[:LIKED]->(comment38)

CREATE
  (post20: Post {
    id: "post20",
    timestamp: "2023-12-04T12:00:00",
    content: "Spending the day painting. It's a great way to express creativity. #Art"
  }),
  (comment39: Comment {
    id: "comment39",
    text: "Art is such a wonderful outlet. What are you painting?",
    timestamp: "2023-12-04T12:30:00"
  }),
  (comment40: Comment {
    id: "comment40",
    text: "Would love to see your work when it's finished!",
    timestamp: "2023-12-04T13:00:00"
  }),
  (user1)-[:CREATED]->(post20),
  (user23)-[:CREATED]->(comment39),
  (user14)-[:CREATED]->(comment40),
  (post20)-[:HAS_COMMENT]->(comment39),
  (post20)-[:HAS_COMMENT]->(comment40),
  (user22)-[:LIKED]->(post20),
  (user20)-[:LIKED]->(post20),
  (user18)-[:LIKED]->(post20),
  (user10)-[:LIKED]->(comment39),
  (user15)-[:LIKED]->(comment39),
  (user22)-[:LIKED]->(comment40),
  (user28)-[:LIKED]->(comment40)

CREATE
  (post21: Post {
    id: "post21",
    timestamp: "2023-11-28T10:00:00",
    content: "Morning run by the river! Never gets old. #MorningRun #RiverView"
  }),
  (comment41: Comment {
    id: "comment41",
    text: "Looks like the perfect running spot!",
    timestamp: "2023-11-28T10:30:00"
  }),
  (comment42: Comment {
    id: "comment42",
    text: "Running by the river is always so peaceful.",
    timestamp: "2023-11-28T11:00:00"
  }),
  (user8)-[:CREATED]->(post21),
  (user10)-[:CREATED]->(comment41),
  (user12)-[:CREATED]->(comment42),
  (post21)-[:HAS_COMMENT]->(comment41),
  (post21)-[:HAS_COMMENT]->(comment42),
  (user2)-[:LIKED]->(post21),
  (user4)-[:LIKED]->(post21),
  (user6)-[:LIKED]->(post21),
  (user14)-[:LIKED]->(comment41),
  (user16)-[:LIKED]->(comment42)

CREATE
  (post22: Post {
    id: "post22",
    timestamp: "2023-11-29T15:00:00",
    content: "Just baked some delicious chocolate chip cookies! #Baking #Cookies"
  }),
  (comment43: Comment {
    id: "comment43",
    text: "They look amazing! Can you share the recipe?",
    timestamp: "2023-11-29T15:30:00"
  }),
  (comment44: Comment {
    id: "comment44",
    text: "Nothing beats homemade cookies!",
    timestamp: "2023-11-29T16:00:00"
  }),
  (comment45: Comment {
    id: "comment45",
    text: "I can almost smell them from here!",
    timestamp: "2023-11-29T16:30:00"
  }),
  (user17)-[:CREATED]->(post22),
  (user19)-[:CREATED]->(comment43),
  (user21)-[:CREATED]->(comment44),
  (user23)-[:CREATED]->(comment45),
  (post22)-[:HAS_COMMENT]->(comment43),
  (post22)-[:HAS_COMMENT]->(comment44),
  (post22)-[:HAS_COMMENT]->(comment45),
  (user1)-[:LIKED]->(post22),
  (user3)-[:LIKED]->(post22),
  (user5)-[:LIKED]->(post22),
  (user7)-[:LIKED]->(comment43),
  (user9)-[:LIKED]->(comment44),
  (user11)-[:LIKED]->(comment45)

CREATE
  (post23: Post {
    id: "post23",
    timestamp: "2023-11-30T20:00:00",
    content: "Amazing night sky photography session. #AstroPhotography #NightSky"
  }),
  (comment46: Comment {
    id: "comment46",
    text: "These pictures are out of this world!",
    timestamp: "2023-11-30T20:30:00"
  }),
  (comment47: Comment {
    id: "comment47",
    text: "What camera settings did you use for these shots?",
    timestamp: "2023-11-30T21:00:00"
  }),
  (comment48: Comment {
    id: "comment48",
    text: "I've always wanted to try astrophotography!",
    timestamp: "2023-11-30T21:30:00"
  }),
  (comment49: Comment {
    id: "comment49",
    text: "Stunning captures!",
    timestamp: "2023-11-30T22:00:00"
  }),
  (user24)-[:CREATED]->(post23),
  (user26)-[:CREATED]->(comment46),
  (user28)-[:CREATED]->(comment47),
  (user2)-[:CREATED]->(comment48),
  (user4)-[:CREATED]->(comment49),
  (post23)-[:HAS_COMMENT]->(comment46),
  (post23)-[:HAS_COMMENT]->(comment47),
  (post23)-[:HAS_COMMENT]->(comment48),
  (post23)-[:HAS_COMMENT]->(comment49),
  (user1)-[:LIKED]->(post23),
  (user3)-[:LIKED]->(post23),
  (user5)-[:LIKED]->(post23),
  (user6)-[:LIKED]->(comment46),
  (user7)-[:LIKED]->(comment47),
  (user8)-[:LIKED]->(comment48),
  (user9)-[:LIKED]->(comment49)

CREATE
  (post24: Post {
    id: "post24",
    timestamp: "2023-12-01T12:30:00",
    content: "Exploring the local farmers' market. So many fresh goodies! #FarmersMarket #FreshProduce"
  }),
  (comment50: Comment {
    id: "comment50",
    text: "Love supporting local farmers!",
    timestamp: "2023-12-01T13:00:00"
  }),
  (comment51: Comment {
    id: "comment51",
    text: "What did you end up buying?",
    timestamp: "2023-12-01T13:30:00"
  }),
  (user20)-[:CREATED]->(post24),
  (user22)-[:CREATED]->(comment50),
  (user25)-[:CREATED]->(comment51),
  (post24)-[:HAS_COMMENT]->(comment50),
  (post24)-[:HAS_COMMENT]->(comment51),
  (user10)-[:LIKED]->(post24),
  (user12)-[:LIKED]->(post24),
  (user14)-[:LIKED]->(post24),
  (user15)-[:LIKED]->(comment50),
  (user16)-[:LIKED]->(comment51)

CREATE
  (post25: Post {
    id: "post25",
    timestamp: "2023-12-02T18:45:00",
    content: "A night out at my favorite jazz club. Great music, great vibes. #JazzNight #LiveMusic"
  }),
  (comment52: Comment {
    id: "comment52",
    text: "Jazz nights are the best. Enjoy!",
    timestamp: "2023-12-02T19:00:00"
  }),
  (comment53: Comment {
    id: "comment53",
    text: "Which club is this? I'd love to check it out!",
    timestamp: "2023-12-02T19:30:00"
  }),
  (user13)-[:CREATED]->(post25),
  (user15)-[:CREATED]->(comment52),
  (user17)-[:CREATED]->(comment53),
  (post25)-[:HAS_COMMENT]->(comment52),
  (post25)-[:HAS_COMMENT]->(comment53),
  (user18)-[:LIKED]->(post25),
  (user19)-[:LIKED]->(post25),
  (user21)-[:LIKED]->(post25),
  (user22)-[:LIKED]->(comment52),
  (user23)-[:LIKED]->(comment53)

CREATE
  (post26: Post {
    id: "post26",
    timestamp: "2023-12-03T09:00:00",
    content: "Great hike this morning, the views were breathtaking! #HikingAdventures"
  }),
  (comment54: Comment {
    id: "comment54",
    text: "Looks like a perfect day for a hike!",
    timestamp: "2023-12-03T09:30:00"
  }),
  (comment55: Comment {
    id: "comment55",
    text: "Which trail did you take?",
    timestamp: "2023-12-03T10:00:00"
  }),
  (user1)-[:CREATED]->(post26),
  (user2)-[:CREATED]->(comment54),
  (user3)-[:CREATED]->(comment55),
  (post26)-[:HAS_COMMENT]->(comment54),
  (post26)-[:HAS_COMMENT]->(comment55),
  (user4)-[:LIKED]->(post26),
  (user5)-[:LIKED]->(post26),
  (user6)-[:LIKED]->(post26)

CREATE
  (post27: Post {
    id: "post27",
    timestamp: "2023-12-04T14:00:00",
    content: "Spent the day at the tech conference, lots of exciting stuff coming up! #TechLife"
  }),
  (comment56: Comment {
    id: "comment56",
    text: "Any interesting startups you'd recommend?",
    timestamp: "2023-12-04T14:30:00"
  }),
  (comment57: Comment {
    id: "comment57",
    text: "Tech conferences are always so inspiring!",
    timestamp: "2023-12-04T15:00:00"
  }),
  (user7)-[:CREATED]->(post27),
  (user8)-[:CREATED]->(comment56),
  (user9)-[:CREATED]->(comment57),
  (post27)-[:HAS_COMMENT]->(comment56),
  (post27)-[:HAS_COMMENT]->(comment57),
  (user10)-[:LIKED]->(post27),
  (user11)-[:LIKED]->(post27),
  (user12)-[:LIKED]->(post27)

CREATE
  (post28: Post {
    id: "post28",
    timestamp: "2023-12-05T19:30:00",
    content: "Homemade pizza night! #CookingAtHome #PizzaLover"
  }),
  (comment58: Comment {
    id: "comment58",
    text: "That looks delicious!",
    timestamp: "2023-12-05T20:00:00"
  }),
  (comment59: Comment {
    id: "comment59",
    text: "I need the recipe for that crust!",
    timestamp: "2023-12-05T20:30:00"
  }),
  (user13)-[:CREATED]->(post28),
  (user14)-[:CREATED]->(comment58),
  (user15)-[:CREATED]->(comment59),
  (post28)-[:HAS_COMMENT]->(comment58),
  (post28)-[:HAS_COMMENT]->(comment59),
  (user16)-[:LIKED]->(post28),
  (user17)-[:LIKED]->(post28),
  (user18)-[:LIKED]->(post28)

CREATE
  (post29: Post {
    id: "post29",
    timestamp: "2023-12-06T08:15:00",
    content: "Early morning yoga session. Feeling refreshed and ready for the day! #Yoga"
  }),
  (comment60: Comment {
    id: "comment60",
    text: "Yoga is the best way to start the day!",
    timestamp: "2023-12-06T08:45:00"
  }),
  (comment61: Comment {
    id: "comment61",
    text: "What's your favorite yoga pose?",
    timestamp: "2023-12-06T09:00:00"
  }),
  (user19)-[:CREATED]->(post29),
  (user20)-[:CREATED]->(comment60),
  (user21)-[:CREATED]->(comment61),
  (post29)-[:HAS_COMMENT]->(comment60),
  (post29)-[:HAS_COMMENT]->(comment61),
  (user22)-[:LIKED]->(post29),
  (user23)-[:LIKED]->(post29),
  (user24)-[:LIKED]->(post29)

CREATE
  (post30: Post {
    id: "post30",
    timestamp: "2023-12-07T17:00:00",
    content: "Catching the sunset at the beach. Perfect end to the day. #Sunset #BeachLife"
  }),
  (comment62: Comment {
    id: "comment62",
    text: "Beach sunsets are the best!",
    timestamp: "2023-12-07T17:30:00"
  }),
  (comment63: Comment {
    id: "comment63",
    text: "Looks so peaceful!",
    timestamp: "2023-12-07T18:00:00"
  }),
  (comment64: Comment {
    id: "comment64",
    text: "Wish I was there!",
    timestamp: "2023-12-07T18:30:00"
  }),
  (user25)-[:CREATED]->(post30),
  (user26)-[:CREATED]->(comment62),
  (user27)-[:CREATED]->(comment63),
  (user28)-[:CREATED]->(comment64),
  (post30)-[:HAS_COMMENT]->(comment62),
  (post30)-[:HAS_COMMENT]->(comment63),
  (post30)-[:HAS_COMMENT]->(comment64),
  (user1)-[:LIKED]->(post30),
  (user2)-[:LIKED]->(post30),
  (user3)-[:LIKED]->(post30)
"""

# import data in neo4j
session.run(query)
